# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive/"
base_dir = root_dir + 'BreastCancer'
# Out:
# Mounted at /content/gdrive

# %%
# Change the working directory
# %cd /content/gdrive/My\ Drive/BreastCancer/IDC_regular_ps50_idx5
# Out:
# /content/gdrive/My Drive/BreastCancer/IDC_regular_ps50_idx5

# %%
from fastai.vision.all import *

# Load the trained FastAI model
model_path = "breast-cancer-rn50.pkl"
learn = load_learner(model_path)

# %%
print(learn.dls.c)  # Should be 1 for single-label, >1 for multi-label
print(learn.dls.vocab)  # Shows the class labels
# Out:
# 2
# ['0', '1']

# %%
# %cd /content/gdrive/My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
print(learn.dls.vocab)
# Out:
# ['0', '1']

# %%
# Replace with the actual path to the image in Google Drive
img_path = "10268_idx5_x2301_y1501_class0.png"

# Load and predict
img = PILImage.create(img_path)
img.show()
pred_class, pred_idx, outputs = learn.predict(img)

probs = F.softmax(outputs, dim=0)
predicted_class = torch.argmax(probs).item()

# Print results
print(f"Predicted Class: {predicted_class}")
print(f"Class Probabilities: {probs.tolist()}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Predicted Class: 0
# Class Probabilities: [0.5880641341209412, 0.41193583607673645]

# %%
# !ls
# Out:
#  10264_idx5_x1351_y1701_class1.png   10268_idx5_x1851_y1151_class0.png
#  10264_idx5_x1351_y451_class1.png    10268_idx5_x1851_y1201_class0.png
#  10264_idx5_x1351_y501_class1.png    10268_idx5_x1851_y1251_class0.png
#  10264_idx5_x1351_y551_class1.png    10268_idx5_x1851_y1301_class0.png
#  10264_idx5_x1351_y601_class1.png    10268_idx5_x1851_y1351_class0.png
#  10264_idx5_x1351_y651_class1.png    10268_idx5_x1851_y1401_class0.png
#  10264_idx5_x1351_y701_class1.png    10268_idx5_x1851_y201_class0.png
#  10264_idx5_x1351_y801_class1.png    10268_idx5_x1851_y251_class0.png
#  10264_idx5_x1351_y851_class1.png    10268_idx5_x1851_y301_class0.png
#  10264_idx5_x1351_y901_class1.png    10268_idx5_x1851_y351_class0.png
#  10264_idx5_x1351_y951_class1.png    10268_idx5_x1851_y401_class0.png
#  10264_idx5_x1401_y1001_class1.png   10268_idx5_x1851_y451_class0.png
#  10264_idx5_x1401_y1051_class1.png   10268_idx5_x1851_y501_class0.png
# ...
